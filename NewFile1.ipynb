# %%
import numpy as np

# %%
# %%time
for R in range(500):
    M = np.random.random((1000000,100))
    N = np.random.random((100,1))
    print(M)
    print(N)
    R = np.matmul(M,N)
    print(R)
# Out:
# [[0.12390634 0.68151753 0.97920864 ... 0.24106438 0.79114095 0.35743199]
#  [0.96063361 0.17825147 0.92201144 ... 0.43326261 0.06755835 0.81663838]
#  [0.96360947 0.57114843 0.37472824 ... 0.49773439 0.98031638 0.39890562]
#  ...
#  [0.16453286 0.68044721 0.39342541 ... 0.56749288 0.07879714 0.57438347]
#  [0.94147767 0.55353782 0.81179638 ... 0.55226255 0.00380264 0.08144877]
#  [0.74078256 0.15855875 0.02312454 ... 0.09377621 0.16567179 0.87876784]]
# [[0.6103879 ]
#  [0.43609869]
#  [0.39161404]
#  [0.93922996]
#  [0.332675  ]
#  [0.58929861]
#  [0.48579481]
#  [0.87582326]
#  [0.80587058]
#  [0.01130627]
#  [0.54903799]
#  [0.76358496]
#  [0.77958196]
#  [0.81634117]
#  [0.55033984]
#  [0.83185711]
#  [0.0367614 ]
#  [0.0142261 ]
#  [0.68645844]
#  [0.49586361]
#  [0.55440333]
#  [0.04402431]
#  [0.30274499]
#  [0.47777904]
#  [0.72299571]
#  [0.67458866]
#  [0.61013507]
#  [0.72345911]
#  [0.0415225 ]
#  [0.24942839]
#  [0.87284612]
#  [0.76410131]
#  [0.8635822 ]
# ...
