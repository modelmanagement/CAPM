# %%
import numpy as np

# %%
# %%time
for R in range(500):
    M = np.random.random((1000000,100))
    N = np.random.random((100,1))
    print(M)
    print(N)
    R = np.matmul(M,N)
    print(R)
# Out:
# [[0.20774084 0.34312845 0.01774453 ... 0.95304812 0.46732667 0.66542522]
#  [0.76322883 0.15301144 0.38678093 ... 0.06809085 0.0404932  0.39915679]
#  [0.17690184 0.12216456 0.36531373 ... 0.71194367 0.36810135 0.55671199]
#  ...
#  [0.98744858 0.37756104 0.34691297 ... 0.18780322 0.58167071 0.5296729 ]
#  [0.17981972 0.33146257 0.61645399 ... 0.71152562 0.51387397 0.46984565]
#  [0.73049383 0.52171798 0.29086948 ... 0.85485864 0.3934235  0.90361306]]
# [[0.01245991]
#  [0.53077107]
#  [0.43233203]
#  [0.170537  ]
#  [0.76042929]
#  [0.92471931]
#  [0.58621147]
#  [0.75283269]
#  [0.29984595]
#  [0.29393486]
#  [0.61891606]
#  [0.37595134]
#  [0.1843414 ]
#  [0.64865437]
#  [0.54140419]
#  [0.51713158]
#  [0.37291622]
#  [0.70378566]
#  [0.00666926]
#  [0.82797692]
#  [0.78298579]
#  [0.93683672]
#  [0.12180926]
#  [0.89440946]
#  [0.44153177]
#  [0.25578848]
#  [0.24331639]
#  [0.18769667]
#  [0.9608035 ]
#  [0.27497707]
#  [0.4466279 ]
#  [0.80444462]
#  [0.08397959]
# ...
